# %%
# API Requests
import pprint
import requests
import json
import time

# Data Science
import pandas as pd
import numpy as np
import scipy.stats as sc
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Geocoding
from api_keys import opencage_key
from api_keys import geoapify_key

# %%
# Create a file path
filepath_cards = "../Resources/cards_data.csv"
filepath_users = "../Resources/users_data.csv"
# Read in the data.
df_cards = pd.read_csv(filepath_cards)
df_users = pd.read_csv(filepath_users)

# %%
df_cards.info()
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   object
#  3   card_type              6146 non-null   object
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   object
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   object
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   object
#  10  acct_open_date         6146 non-null   object
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 624.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2000 non-null   int64
#  1   current_age        2000 non-null   int64
#  2   retirement_age     2000 non-null   int64
#  3   birth_year         2000 non-null   int64
#  4   birth_month        2000 non-null   int64
#  5   gender             2000 non-null   object
#  6   address            2000 non-null   object
#  7   latitude           2000 non-null   float64
#  8   longitude          2000 non-null   float64
#  9   per_capita_income  2000 non-null   object
#  10  yearly_income      2000 non-null   object
#  11  total_debt         2000 non-null   object
#  12  credit_score       2000 non-null   int64
#  13  num_credit_cards   2000 non-null   int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 218.9+ KB

# %%
# Merging noth files on ID column
df = pd.merge(df_cards, df_users, left_on="client_id", right_on="id", how="inner")
df.head()
# Out:
#    id_x  client_id  card_brand        card_type       card_number  expires  \
# 0  4524        825        Visa            Debit  4344676511950444  12/2022
# 1  2731        825        Visa            Debit  4956965974959986  12/2020
# 2  3701        825        Visa            Debit  4582313478255491  02/2024
# 3    42        825        Visa           Credit  4879494103069057  08/2024
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    cvv has_chip  num_cards_issued credit_limit  ... birth_month  gender  \
# 0  623      YES                 2       $24295  ...          11  Female
# 1  393      YES                 2       $21968  ...          11  Female
# 2  719      YES                 2       $46414  ...          11  Female
# 3  693       NO                 1       $12400  ...          11  Female
# 4   75      YES                 1          $28  ...          11  Female
#
#          address  latitude  longitude  per_capita_income  yearly_income  \
# 0  462 Rose Lane     34.15    -117.76             $29278         $59696
# 1  462 Rose Lane     34.15    -117.76             $29278         $59696
# 2  462 Rose Lane     34.15    -117.76             $29278         $59696
# 3  462 Rose Lane     34.15    -117.76             $29278         $59696
# 4  462 Rose Lane     34.15    -117.76             $29278         $59696
#
#    total_debt credit_score num_credit_cards
# 0     $127613          787                5
# 1     $127613          787                5
# 2     $127613          787                5
# 3     $127613          787                5
# 4     $127613          787                5
#
# [5 rows x 27 columns]

# %%
# Removing dollar sign from monetary columlns
df["credit_limit"] = df.credit_limit.str.strip("$")
df["per_capita_income"] = df.per_capita_income.str.strip("$")
df["yearly_income"] = df.yearly_income.str.strip("$")
df["total_debt"] = df.total_debt.str.strip("$")
df.head()
# Out:
#    id_x  client_id  card_brand        card_type       card_number  expires  \
# 0  4524        825        Visa            Debit  4344676511950444  12/2022
# 1  2731        825        Visa            Debit  4956965974959986  12/2020
# 2  3701        825        Visa            Debit  4582313478255491  02/2024
# 3    42        825        Visa           Credit  4879494103069057  08/2024
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    cvv has_chip  num_cards_issued credit_limit  ... birth_month  gender  \
# 0  623      YES                 2        24295  ...          11  Female
# 1  393      YES                 2        21968  ...          11  Female
# 2  719      YES                 2        46414  ...          11  Female
# 3  693       NO                 1        12400  ...          11  Female
# 4   75      YES                 1           28  ...          11  Female
#
#          address  latitude  longitude  per_capita_income  yearly_income  \
# 0  462 Rose Lane     34.15    -117.76              29278          59696
# 1  462 Rose Lane     34.15    -117.76              29278          59696
# 2  462 Rose Lane     34.15    -117.76              29278          59696
# 3  462 Rose Lane     34.15    -117.76              29278          59696
# 4  462 Rose Lane     34.15    -117.76              29278          59696
#
#    total_debt credit_score num_credit_cards
# 0      127613          787                5
# 1      127613          787                5
# 2      127613          787                5
# 3      127613          787                5
# 4      127613          787                5
#
# [5 rows x 27 columns]

# %%
# Converting objects to int value
df["credit_limit"] = df["credit_limit"].astype(int)
df["per_capita_income"] = df["per_capita_income"].astype(int)
df["yearly_income"] = df["yearly_income"].astype(int)
df["total_debt"] =df["total_debt"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_x                   6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   object
#  3   card_type              6146 non-null   object
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   object
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   object
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   int32
#  10  acct_open_date         6146 non-null   object
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   object
#  13  id_y                   6146 non-null   int64
#  14  current_age            6146 non-null   int64
#  15  retirement_age         6146 non-null   int64
#  16  birth_year             6146 non-null   int64
#  17  birth_month            6146 non-null   int64
#  18  gender                 6146 non-null   object
#  19  address                6146 non-null   object
#  20  latitude               6146 non-null   float64
#  21  longitude              6146 non-null   float64
#  22  per_capita_income      6146 non-null   int32
#  23  yearly_income          6146 non-null   int32
#  24  total_debt             6146 non-null   int32
#  25  credit_score           6146 non-null   int64
#  26  num_credit_cards       6146 non-null   int64
# dtypes: float64(2), int32(4), int64(13), object(8)
# memory usage: 1.2+ MB

# %%
# Remove duplicates by client_id
df2 = df.drop_duplicates(subset='client_id', keep='first')

# Checking the result after removing duplicates
df2.head()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 0 to 6144
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_x                   2000 non-null   int64
#  1   client_id              2000 non-null   int64
#  2   card_brand             2000 non-null   object
#  3   card_type              2000 non-null   object
#  4   card_number            2000 non-null   int64
#  5   expires                2000 non-null   object
#  6   cvv                    2000 non-null   int64
#  7   has_chip               2000 non-null   object
#  8   num_cards_issued       2000 non-null   int64
#  9   credit_limit           2000 non-null   int32
#  10  acct_open_date         2000 non-null   object
#  11  year_pin_last_changed  2000 non-null   int64
#  12  card_on_dark_web       2000 non-null   object
#  13  id_y                   2000 non-null   int64
#  14  current_age            2000 non-null   int64
#  15  retirement_age         2000 non-null   int64
#  16  birth_year             2000 non-null   int64
#  17  birth_month            2000 non-null   int64
#  18  gender                 2000 non-null   object
#  19  address                2000 non-null   object
#  20  latitude               2000 non-null   float64
#  21  longitude              2000 non-null   float64
#  22  per_capita_income      2000 non-null   int32
#  23  yearly_income          2000 non-null   int32
#  24  total_debt             2000 non-null   int32
#  25  credit_score           2000 non-null   int64
#  26  num_credit_cards       2000 non-null   int64
# dtypes: float64(2), int32(4), int64(13), object(8)
# memory usage: 406.2+ KB

# %%
# Drop the specified columns
df2 = df2.drop(columns=['id_x', 'card_brand', 'card_type', 'card_number', 'expires', 'cvv', 'has_chip', 'num_cards_issued', 'credit_limit', 'acct_open_date', 'year_pin_last_changed', 'card_on_dark_web', 'id_y', 'retirement_age'])

# Checking the result after dropping the columns
df2.head()
# Out:
#     client_id  current_age  birth_year  birth_month  gender  \
# 0         825           53        1966           11  Female
# 5        1746           53        1966           12  Female
# 10       1718           81        1938           11  Female
# 15        708           63        1957            1  Female
# 19       1164           43        1976            9    Male
#
#                      address  latitude  longitude  per_capita_income  \
# 0              462 Rose Lane     34.15    -117.76              29278
# 5     3606 Federal Boulevard     40.76     -73.74              37891
# 10           766 Third Drive     34.02    -117.89              22681
# 15          3 Madison Street     40.71     -73.99             163145
# 19  9620 Valley Stream Drive     37.76    -122.44              53797
#
#     yearly_income  total_debt  credit_score  num_credit_cards
# 0           59696      127613           787                 5
# 5           77254      191349           701                 5
# 10          33483         196           698                 5
# 15         249925      202328           722                 4
# 19         109687      183855           675                 1

# %%
# Create new Debt to Income column

df2['debt_to_income'] = df2['total_debt'] / df2['yearly_income']
df2
# Out:
#       client_id  current_age  birth_year  birth_month  gender  \
# 0           825           53        1966           11  Female
# 5          1746           53        1966           12  Female
# 10         1718           81        1938           11  Female
# 15          708           63        1957            1  Female
# 19         1164           43        1976            9    Male
# ...         ...          ...         ...          ...     ...
# 6133        986           32        1987            7    Male
# 6136       1944           62        1957           11  Female
# 6140        185           47        1973            1  Female
# 6143       1007           66        1954            2    Male
# 6144       1110           21        1998           11  Female
#
#                        address  latitude  longitude  per_capita_income  \
# 0                462 Rose Lane     34.15    -117.76              29278
# 5       3606 Federal Boulevard     40.76     -73.74              37891
# 10             766 Third Drive     34.02    -117.89              22681
# 15            3 Madison Street     40.71     -73.99             163145
# 19    9620 Valley Stream Drive     37.76    -122.44              53797
# ...                        ...       ...        ...                ...
# 6133       6577 Lexington Lane     40.65     -73.58              23550
# 6136               2 Elm Drive     38.95     -84.54              24218
# 6140       276 Fifth Boulevard     40.66     -74.19              15175
# 6143      259 Valley Boulevard     40.24     -76.92              25336
# 6144     472 Ocean View Street     42.86     -71.48              32325
#
#       yearly_income  total_debt  credit_score  num_credit_cards  \
# 0             59696      127613           787                 5
# 5             77254      191349           701                 5
# 10            33483         196           698                 5
# 15           249925      202328           722                 4
# 19           109687      183855           675                 1
# ...             ...         ...           ...               ...
# 6133          48010       87837           703                 3
# 6136          49378      104480           740                 4
# 6140          30942       71066           779                 3
# 6143          54654       27241           618                 1
# 6144          65909      181261           673                 2
#
#       debt_to_income
# 0           2.137714
# 5           2.476881
# 10          0.005854
# 15          0.809555
# 19          1.676179
# ...              ...
# 6133        1.829556
# 6136        2.115922
# 6140        2.296749
# 6143        0.498426
# 6144        2.750171
#
# [2000 rows x 14 columns]

# %%
# Create the reverse Geocode function
def reverse_geocode(lat, lng, api_key):
    base_url = "https://api.opencagedata.com/geocode/v1/json"
    params = {
        "q": f"{lat},{lng}",
        "key": api_key,  # Using the API key passed from the imported file
        "language": "en",
        "pretty": 1
    }
    
    # Make the API request
    response = requests.get(base_url, params=params)
    
    # Debugging: Print out the status and the response body
    print(f"Requesting coordinates: {lat}, {lng}")
    print(f"Status Code: {response.status_code}")
    
    if response.status_code == 200:
        data = response.json()
        # Check if there are results
        if data['results']:
            print(f"Address found: {data['results'][0]['formatted']}")
            return data['results'][0]['formatted']
        else:
            print("No results found.")
            return "No results found"
    else:
        # Print the error message and response
        print(f"Error: {response.status_code}")
        print(response.text)  # This will print the response text for error details
        return f"Error: {response.status_code}"

# Add a 1-second delay to avoid overloading the API
def delayed_reverse_geocode(lat, lng, api_key):
    time.sleep(1)  # Sleep for 1 second between requests
    return reverse_geocode(lat, lng, api_key)

# Loop the reverse goecode through each row
df2['address'] = df2.apply(lambda row: delayed_reverse_geocode(row['latitude'], row['longitude'], opencage_key), axis=1)

# Check the result
df2.head()
# Out:
# Requesting coordinates: 34.15, -117.76
# Status Code: 200
# Address found: 7481 Brydon Road, La Verne, CA 91750, United States of America
# Requesting coordinates: 40.76, -73.74
# Status Code: 200
# Address found: 51-17 Redfield Street, New York, NY 11362, United States of America
# Requesting coordinates: 34.02, -117.89
# Status Code: 200
# Address found: Nogales Street, West Covina, CA 91792, United States of America
# Requesting coordinates: 40.71, -73.99
# Status Code: 200
# Address found: Market Slip, New York, NY 10002, United States of America
# Requesting coordinates: 37.76, -122.44
# Status Code: 200
# Address found: 24;26 Caselli Avenue, San Francisco, CA 94114, United States of America
# Requesting coordinates: 41.55, -90.6
# Status Code: 200
# Address found: Adams Elementary School, 3029 North Division Street, Davenport, IA 52804, United States of America
# Requesting coordinates: 38.22, -85.74
# Status Code: 200
# Address found: 1126 Forrest Street, Germantown, Louisville, KY 40217, United States of America
# Requesting coordinates: 45.51, -122.64
# Status Code: 200
# Address found: 1818 Southeast 25th Avenue, Portland, OR 97214, United States of America
# Requesting coordinates: 40.32, -75.32
# Status Code: 200
# Address found: 522 South Main Street, Telford, Bucks County, PA 18969, United States of America
# Requesting coordinates: 29.97, -92.12
# Status Code: 200
# Address found: 235 Rue Alleman, Abbeville, LA 70510, United States of America
# Requesting coordinates: 38.65, -121.25
# Status Code: 200
# Address found: 4701 Hillcrest Avenue, Sacramento County, CA 95628, United States of America
# Requesting coordinates: 40.42, -104.74
# Status Code: 200
# Address found: 1207 38th Avenue, Greeley, CO 80634, United States of America
# Requesting coordinates: 41.76, -71.48
# Status Code: 200
# Address found: I 295, Cranston, RI 02920, United States of America
# Requesting coordinates: 44.75, -85.6
# Status Code: 200
# Address found: Traverse Heights Elementary School, 933 Rose Street, Traverse City, MI 49686, United States of America
# Requesting coordinates: 29.45, -98.5
# Status Code: 200
# Address found: Philo Coffee, 606 West French Place, San Antonio, TX 78212, United States of America
# Requesting coordinates: 36.73, -102.51
# Status Code: 200
# Address found: North Murray Avenue, Boise City, OK 73933, United States of America
# Requesting coordinates: 32.15, -94.79
# Status Code: 200
# Address found: 398 South Oak Street, Henderson, TX 75654, United States of America
# Requesting coordinates: 35.29, -111.32
# Status Code: 200
# Address found: Hopi Road, Coconino County, AZ, United States of America
# Requesting coordinates: 35.19, -80.83
# Status Code: 200
# Address found: Queens Road, Charlotte, NC 28274, United States of America
# Requesting coordinates: 32.21, -110.88
# Status Code: 200
# Address found: 5283 East 20th Street, Tucson, AZ 85711, United States of America
# Requesting coordinates: 32.07, -82.91
# Status Code: 200
# Address found: 8 South Albany Avenue, McRae–Helena, GA 31037, United States of America
# Requesting coordinates: 37.37, -122.21
# Status Code: 200
# Address found: 18 Saddleback Drive, Portola Valley, San Mateo County, CA 94028, United States of America
# Requesting coordinates: 41.47, -81.67
# Status Code: 200
# Address found: unnamed road, Cleveland, OH 44127, United States of America
# Requesting coordinates: 35.49, -90.35
# Status Code: 200
# Address found: Terry Drive, Tyronza, Poinsett County, AR 72386, United States of America
# Requesting coordinates: 42.39, -122.93
# Status Code: 200
# Address found: 2284 Scenic Avenue, Central Point, OR 97502, United States of America
# Requesting coordinates: 33.44, -111.85
# Status Code: 200
# Address found: Mesa Country Club Golf Course, 660 West Fairway Drive, Mesa, AZ 85201, United States of America
# Requesting coordinates: 29.76, -95.38
# Status Code: 200
# Address found: 1701 Bluebonnet Place Circle, Houston, TX 77019, United States of America
# Requesting coordinates: 34.17, -118.46
# Status Code: 200
# Address found: 5513 Lemona Avenue, Los Angeles, CA 91411, United States of America
# Requesting coordinates: 36.15, -85.5
# Status Code: 200
# Address found: Commerce Avenue, Capshaw Woods, Cookeville, TN 38503, United States of America
# Requesting coordinates: 36.28, -86.83
# Status Code: 200
# Address found: Whites Creek Pike, Whites Creek, Nashville-Davidson, TN 37080, United States of America
# Requesting coordinates: 39.98, -82.98
# Status Code: 200
# Address found: 698 St Clair Avenue, Columbus, OH 43201, United States of America
# Requesting coordinates: 25.77, -80.2
# Status Code: 200
# Address found: 342 Southwest 4th Street, Miami, FL 33130, United States of America
# Requesting coordinates: 33.92, -78.02
# Status Code: 200
# Address found: Ricky Evans Gallery, North Howe Street, Southport, NC 28461, United States of America
# Requesting coordinates: 41.29, -72.36
# Status Code: 200
# Address found: 91 North Cove Road, Saybrook Point, Old Saybrook, CT 06475, United States of America
# Requesting coordinates: 30.68, -88.04
# Status Code: 200
# Address found: Mobile County Sheriff's Office, 510 South Royal Street, Mobile, AL 36601, United States of America
# Requesting coordinates: 38.48, -121.34
# Status Code: 200
# Address found: unnamed road, Elk Grove, CA 95829, United States of America
# Requesting coordinates: 32.61, -117.03
# Status Code: 200
# Address found: 1447 Laurel Avenue, Chula Vista, CA 91911, United States of America
# Requesting coordinates: 41.97, -88.14
# Status Code: 200
# Address found: Mallard Lake Bicycle Trail, Hanover Park, DuPage County, IL 60133, United States of America
# Requesting coordinates: 36.62, -121.82
# Status Code: 200
# Address found: North Garden Avenue, Seaside, CA 93955, United States of America
# Requesting coordinates: 42.31, -71.64
# Status Code: 200
# Address found: 21 Joseph Road, Northborough, MA 01581, United States of America
# Requesting coordinates: 38.9, -94.68
# Status Code: 200
# Address found: Marillac, 8000 West 127th Street, Overland Park, KS 66213, United States of America
# Requesting coordinates: 27.8, -97.39
# Status Code: 200
# Address found: Corpus Christi Marina, 400A North Shoreline Boulevard, Corpus Christi, TX 78401, United States of America
# Requesting coordinates: 33.27, -111.94
# Status Code: 200
# Address found: Maricopa County, Arizona, United States of America
# Requesting coordinates: 26.41, -81.42
# Status Code: 200
# Address found: 485 Carver Street, Immokalee, FL 34142, United States of America
# Requesting coordinates: 29.1, -81.0
# Status Code: 200
# Address found: 619 Forest Troll Drive, Port Orange, FL 32127, United States of America
# Requesting coordinates: 38.72, -90.47
# Status Code: 200
# Address found: Streetcar Drive, Maryland Heights, MO 63043, United States of America
# Requesting coordinates: 29.45, -98.5
# Status Code: 200
# Address found: Philo Coffee, 606 West French Place, San Antonio, TX 78212, United States of America
# Requesting coordinates: 28.7, -81.34
# Status Code: 200
# Address found: 400 Warren Avenue, Longwood, FL 32750, United States of America
# Requesting coordinates: 43.06, -87.96
# Status Code: 200
# Address found: North 37th Street, Milwaukee, WI 53208, United States of America
# Requesting coordinates: 31.22, -84.21
# Status Code: 200
# Address found: 334 East Camellia Drive, Camilla, Mitchell County, GA 31730, United States of America
# Requesting coordinates: 42.3, -83.48
# Status Code: 200
# Address found: Bentley Elementary School, 1100 South Sheldon Road, Canton Township, MI 48188, United States of America
# Requesting coordinates: 36.37, -84.12
# Status Code: 200
# Address found: 170 Hillside Drive, La Follette, TN 37766, United States of America
# Requesting coordinates: 35.05, -82.09
# Status Code: 200
# Address found: 6 North Howard Street, Inman, SC 29349, United States of America
# Requesting coordinates: 38.47, -81.81
# Status Code: 200
# Address found: Janette Drive, Poca, Putnam County, WV 25159, United States of America
# Requesting coordinates: 30.56, -97.86
# Status Code: 200
# Address found: 942 Honeysuckle Drive, Leander, TX 78641, United States of America
# Requesting coordinates: 40.72, -73.86
# Status Code: 200
# Address found: 65-64 Ellwell Crescent, New York, NY 11374, United States of America
# Requesting coordinates: 33.78, -84.44
# Status Code: 200
# Address found: Proctor Creek Greenway, Simsville, Atlanta, GA 30318, United States of America
# Requesting coordinates: 41.66, -83.58
# Status Code: 200
# Address found: 2000 Hawthorne Street, Auburndale, Toledo, OH 43606, United States of America
# Requesting coordinates: 29.76, -95.38
# Status Code: 200
# Address found: 1701 Bluebonnet Place Circle, Houston, TX 77019, United States of America
# Requesting coordinates: 40.38, -77.88
# Status Code: 200
# Address found: 184 South Moore Avenue, Mount Union, Huntingdon County, PA 17066, United States of America
# Requesting coordinates: 29.45, -98.5
# Status Code: 200
# Address found: Philo Coffee, 606 West French Place, San Antonio, TX 78212, United States of America
# Requesting coordinates: 47.32, -121.99
# Status Code: 200
# Address found: Lake Ginder Road, Black Diamond, King County, WA 98010, United States of America
# Requesting coordinates: 41.31, -111.96
# Status Code: 200
# Address found: 650 East, North Ogden, UT 84414, United States of America
# Requesting coordinates: 32.75, -97.33
# Status Code: 200
# Address found: AT&T Building, 1116 Houston Street, Fort Worth, TX 76102, United States of America
# Requesting coordinates: 40.69, -73.75
# Status Code: 200
# Address found: 120-15 200th Street, New York, NY 11412, United States of America
# Requesting coordinates: 38.68, -76.17
# Status Code: 200
# Address found: 182 River View Avenue, Oxford, Talbot County, MD 21654, United States of America
# Requesting coordinates: 29.5, -97.44
# Status Code: 200
# Address found: 258 Rivercrest Drive, Gonzales, TX 78629, United States of America
# Requesting coordinates: 40.59, -75.47
# Status Code: 200
# Address found: 846 West Wyoming Street, Allentown, PA 18103, United States of America
# Requesting coordinates: 40.39, -82.47
# Status Code: 200
# Address found: 311 South Center Street, Buckingham Court, Mount Vernon, OH 43050, United States of America
# Requesting coordinates: 40.22, -74.76
# Status Code: 200
# Address found: Verizon, 241 East State Street, Trenton, NJ 08619, United States of America
# Requesting coordinates: 33.88, -118.27
# Status Code: 200
# Address found: 389 East 169th Street, Carson, CA 90746, United States of America
# Requesting coordinates: 38.22, -122.55
# Status Code: 200
# Address found: Stage Gulch Road, Sonoma County, CA, United States of America
# Requesting coordinates: 28.68, -81.51
# Status Code: 200
# Address found: 56 East Oak Street, Apopka, FL 32703, United States of America
# Requesting coordinates: 41.77, -87.82
# Status Code: 200
# Address found: unnamed road, Bedford Park, Lyons Township, IL 60501, United States of America
# Requesting coordinates: 32.92, -96.45
# Status Code: 200
# Address found: 1421 Justin Road, Rockwall, TX 75087, United States of America
# Requesting coordinates: 33.52, -86.79
# Status Code: 200
# Address found: Jones Valley Trail, Birmingham, AL 35202, United States of America
# Requesting coordinates: 32.71, -102.65
# Status Code: 200
# Address found: 535 Southwest Avenue H, Seminole, TX 79360, United States of America
# Requesting coordinates: 32.9, -80.93
# Status Code: 200
# Address found: unnamed road, Colleton County, SC 29929, United States of America
# Requesting coordinates: 35.67, -97.41
# Status Code: 200
# Address found: East Danforth Road, Edmond, OK 73034, United States of America
# Requesting coordinates: 48.19, -114.38
# Status Code: 200
# Address found: 1709 Whalebone Drive, Batavia, Flathead County, MT 59901, United States of America
# Requesting coordinates: 30.44, -91.12
# Status Code: 200
# Address found: 1015 Audubon Avenue, Goodwood Estates, Baton Rouge, LA 70806, United States of America
# Requesting coordinates: 40.69, -80.01
# Status Code: 200
# Address found: Park Avenue, Mars, Butler County, PA 16046, United States of America
# Requesting coordinates: 40.43, -79.97
# Status Code: 200
# Address found: River Park Commons, 2403 Sidney Street, Pittsburgh, PA 15203, United States of America
# Requesting coordinates: 34.07, -117.62
# Status Code: 200
# Address found: Ray Wiltsey Middle School, East F Street, Ontario, CA 91764, United States of America
# Requesting coordinates: 33.6, -117.82
# Status Code: 200
# Address found: 32 Via Rubino, Newport Beach, CA 92657, United States of America
# Requesting coordinates: 42.4, -83.6
# Status Code: 200
# Address found: old track, Salem Township, MI 48175, United States of America
# Requesting coordinates: 42.8, -83.71
# Status Code: 200
# Address found: 457 North Adelaide Street, Fenton, MI 48430, United States of America
# Requesting coordinates: 39.72, -82.59
# Status Code: 200
# Address found: 6th North, Lancaster, OH 43130, United States of America
# Requesting coordinates: 30.23, -92.81
# Status Code: 200
# Address found: 199 East Naebers Street, Welsh, LA 70591, United States of America
# Requesting coordinates: 37.78, -122.24
# Status Code: 200
# Address found: Stage Left Cellars, 2100 Dennison Street, Oakland, CA 94501, United States of America
# Requesting coordinates: 40.26, -103.79
# Status Code: 200
# Address found: 800 Fremont Avenue, Fort Morgan, CO 80701, United States of America
# Requesting coordinates: 43.07, -89.38
# Status Code: 200
# Address found: Capital City State Trail, Madison, WI 53788, United States of America
# Requesting coordinates: 30.17, -85.67
# Status Code: 200
# Address found: 702 West 12th Street, Panama City, FL 32401, United States of America
# Requesting coordinates: 33.78, -117.33
# Status Code: 200
# Address found: La Barranca Road, Riverside County, CA, United States of America
# Requesting coordinates: 44.96, -93.26
# Status Code: 200
# Address found: 912 East 24th Street, Minneapolis, MN 55404, United States of America
# Requesting coordinates: 37.3, -122.0
# Status Code: 200
# Address found: 1299 Regency Drive, San Jose, CA 95129, United States of America
# Requesting coordinates: 35.3, -81.03
# Status Code: 200
# Address found: Patrick Lane, Mount Holly, NC 28120, United States of America
# Requesting coordinates: 33.53, -112.18
# Status Code: 200
# Address found: Claremont Street, Glendale, AZ 85301, United States of America
# Requesting coordinates: 26.02, -80.16
# Status Code: 200
# Address found: 2630 Hayes Street, Hollywood, FL 33020, United States of America
# Requesting coordinates: 32.85, -96.96
# Status Code: 200
# Address found: Irving Arts Center, 3333 Coker Street, Irving, TX 75062, United States of America
# Requesting coordinates: 26.63, -81.99
# Status Code: 200
# Address found: 721 Southwest 12th Terrace, Cape Coral, FL 33991, United States of America
# Requesting coordinates: 38.64, -76.9
# Status Code: 200
# Address found: unnamed road, Waldorf, MD 20601, United States of America
# Requesting coordinates: 41.88, -87.84
# Status Code: 200
# Address found: 893 South 6th Avenue, Maywood, IL 60153, United States of America
# Requesting coordinates: 40.66, -73.84
# Status Code: 200
# Address found: 158-29 Cross Bay Boulevard, New York, NY 11414, United States of America
# Requesting coordinates: 30.44, -87.18
# Status Code: 200
# Address found: Hyde Park Road, Pensacola, FL 32503, United States of America
# Requesting coordinates: 40.94, -73.86
# Status Code: 200
# Address found: 64 Elaine Terrace, Bryn Mawr Park, City of Yonkers, NY 10701, United States of America
# Requesting coordinates: 35.72, -78.84
# Status Code: 200
# Address found: 399 Gilby Road, Apex, NC 27502, United States of America
# Requesting coordinates: 41.83, -87.68
# Status Code: 200
# Address found: South Leavitt Street, Chicago, IL 60608, United States of America
# Requesting coordinates: 33.74, -117.99
# Status Code: 200
# Address found: 15321 Beach Boulevard, Westminster, CA 92655, United States of America
# Requesting coordinates: 41.5, -87.5
# Status Code: 200
# Address found: 1129 Deer Creek Drive, Dyer, IN 46311, United States of America
# Requesting coordinates: 33.95, -84.54
# Status Code: 200
# Address found: 422 Roswell Street, Marietta, GA 30060, United States of America
# Requesting coordinates: 42.47, -83.49
# Status Code: 200
# Address found: 24809 Jamestowne Road, Novi, MI 48375, United States of America
# Requesting coordinates: 29.5, -97.44
# Status Code: 200
# Address found: 258 Rivercrest Drive, Gonzales, TX 78629, United States of America
# Requesting coordinates: 39.4, -88.8
# Status Code: 200
# Address found: 645 West South 9th Street, Shelbyville, IL 62565, United States of America
# Requesting coordinates: 35.2, -101.81
# Status Code: 200
# Address found: Tee Anchor Boulevard, Amarillo, TX 79104, United States of America
# Requesting coordinates: 37.68, -97.34
# Status Code: 200
# Address found: 264 West Dewey Street, Wichita, KS 67202, United States of America
# Requesting coordinates: 38.1, -122.63
# Status Code: 200
# Address found: 14 Rebelo Lane, Marin County, CA 94947, United States of America
# Requesting coordinates: 32.08, -81.1
# Status Code: 200
# Address found: 532 West Youmans Street, Savannah, GA 31401, United States of America
# Requesting coordinates: 38.91, -75.43
# Status Code: 200
# Address found: 75 South Maple Avenue, Milford, DE 19963, United States of America
# Requesting coordinates: 43.46, -85.95
# Status Code: 200
# Address found: South Weaver Avenue, Fremont, MI 49412, United States of America
# Requesting coordinates: 34.15, -118.6
# Status Code: 200
# Address found: 4371 Pampas Road, Los Angeles, CA 91364, United States of America
# Requesting coordinates: 43.07, -82.49
# Status Code: 200
# Address found: Brace Road, Fort Gratiot Charter Township, MI 48059, United States of America
# Requesting coordinates: 37.69, -97.13
# Status Code: 200
# Address found: Yorktown Parkway, Andover, Butler County, KS 67002, United States of America
# Requesting coordinates: 43.07, -89.38
# Status Code: 200
# Address found: Capital City State Trail, Madison, WI 53788, United States of America
# Requesting coordinates: 47.09, -116.46
# Status Code: 200
# Address found: Tyson Creek Road, Benewah County, ID, United States of America
# Requesting coordinates: 30.62, -87.89
# Status Code: 200
# Address found: Whispering Pines Road, Jackson Oak, Daphne, AL 36526, United States of America
# Requesting coordinates: 37.83, -122.22
# Status Code: 200
# Address found: 5885 Harbord Drive, Oakland, CA 94611, United States of America
# Requesting coordinates: 33.83, -117.2
# Status Code: 200
# Address found: Old Evans Road, Perris, CA 92571, United States of America
# Requesting coordinates: 32.32, -90.2
# Status Code: 200
# Address found: 699 Erie Street, Jackson, MS 39203, United States of America
# Requesting coordinates: 39.51, -76.17
# Status Code: 200
# Address found: 362 Custis Street, Aberdeen, MD 21001, United States of America
# Requesting coordinates: 41.71, -72.83
# Status Code: 200
# Address found: 99 Reservoir Road, Farmington, CT 06032, United States of America
# Requesting coordinates: 38.71, -95.08
# Status Code: 200
# Address found: East 10th Street, Wellsville, Franklin County, KS 66092, United States of America
# Requesting coordinates: 28.5, -81.37
# Status Code: 200
# Address found: 698 Derry Down Road, Orange County, FL 32806, United States of America
# Requesting coordinates: 43.05, -82.67
# Status Code: 200
# Address found: 8398 Beard Road, Kenockee Township, MI 48006, United States of America
# Requesting coordinates: 32.32, -95.3
# Status Code: 200
# Address found: 2666 South Broadway Avenue, Tyler, TX 75701, United States of America
# Requesting coordinates: 26.63, -81.85
# Status Code: 200
# Address found: 2978 South Street, Fort Myers, FL 33916, United States of America
# Requesting coordinates: 38.88, -94.81
# Status Code: 200
# Address found: 533 East Loula Street, Olathe, KS 66061, United States of America
# Requesting coordinates: 39.45, -76.81
# Status Code: 200
# Address found: 116 East Cherry Hill Road, Reisterstown, MD 21136, United States of America
# Requesting coordinates: 42.38, -83.1
# Status Code: 200
# Address found: Chicago Boulevard, Detroit, MI 48206, United States of America
# Requesting coordinates: 40.64, -73.94
# Status Code: 200
# Address found: 702 East 39th Street, New York, NY 11203, United States of America
# Requesting coordinates: 37.72, -122.44
# Status Code: 200
# Address found: 2006 Alemany Boulevard, San Francisco, CA 94112, United States of America
# Requesting coordinates: 34.95, -96.75
# Status Code: 200
# Address found: 652 North Broadway Street, Konawa, Seminole County, OK 74849, United States of America
# Requesting coordinates: 47.75, -122.04
# Status Code: 200
# Address found: 226th Avenue Northeast, King County, WA 98077, United States of America
# Requesting coordinates: 27.48, -82.57
# Status Code: 200
# Address found: 776 22nd Avenue West, Bradenton, FL 34205, United States of America
# Requesting coordinates: 35.19, -80.83
# Status Code: 200
# Address found: Queens Road, Charlotte, NC 28274, United States of America
# Requesting coordinates: 38.77, -76.06
# Status Code: 200
# Address found: 29201 Heworth Road, Easton, MD 21601, United States of America
# Requesting coordinates: 40.52, -122.32
# Status Code: 200
# Address found: unnamed road, Redding, CA 96002, United States of America
# Requesting coordinates: 42.37, -87.86
# Status Code: 200
# Address found: 2225 Grand Avenue, Waukegan, IL 60085, United States of America
# Requesting coordinates: 31.5, -111.06
# Status Code: 200
# Address found: Wolf Canyon Road, Santa Cruz County, AZ, United States of America
# Requesting coordinates: 35.92, -86.84
# Status Code: 200
# Address found: 698 Westminster Drive, Franklin, TN 37067, United States of America
# Requesting coordinates: 42.13, -87.92
# Status Code: 200
# Address found: 152 Carpenter Avenue, Wheeling, IL 60090, United States of America
# Requesting coordinates: 32.28, -110.73
# Status Code: 200
# Address found: 12287 East Roger Road, Pima County, AZ 85749, United States of America
# Requesting coordinates: 35.1, -90.0
# Status Code: 200
# Address found: 1887 East Person Avenue, Memphis, TN 38114, United States of America
# Requesting coordinates: 40.79, -77.85
# Status Code: 200
# Address found: 203 East McCormick Avenue, State College, PA 16801, United States of America
# Requesting coordinates: 42.28, -71.16
# Status Code: 200
# Address found: 28 Elgin Street, Boston, MA 02132, United States of America
# Requesting coordinates: 41.92, -87.81
# Status Code: 200
# Address found: 2206 North 73rd Court, Elmwood Park, IL 60707, United States of America
# Requesting coordinates: 39.69, -74.25
# Status Code: 200
# Address found: 37 Indian Road, Stafford Township, NJ 08050, United States of America
# Requesting coordinates: 42.62, -73.83
# Status Code: 200
# Address found: Pine View Avenue, Delmar, Bethlehem, NY 12054, United States of America
# Requesting coordinates: 38.04, -84.45
# Status Code: 200
# Address found: S&S Tire, 1475 Jingle Bell Lane, Lexington, KY 40505, United States of America
# Requesting coordinates: 41.55, -73.03
# Status Code: 200
# Address found: 32 Slocum Street, Waterbury, CT 06706, United States of America
# Requesting coordinates: 33.91, -118.23
# Status Code: 200
# Address found: 2243 East Piru Street, Willowbrook, CA 90222, United States of America
# Requesting coordinates: 44.96, -93.26
# Status Code: 200
# Address found: 912 East 24th Street, Minneapolis, MN 55404, United States of America
# Requesting coordinates: 36.49, -81.5
# Status Code: 200
# Address found: 8364 NC 194, Lansing, Ashe County, NC 28643, United States of America
# Requesting coordinates: 36.34, -83.28
# Status Code: 200
# Address found: Lee Highway, Bean Station, Grainger County, TN 37708, United States of America
# Requesting coordinates: 34.06, -117.17
# Status Code: 200
# Address found: 550 Division Street, Redlands, CA 92374, United States of America
# Requesting coordinates: 39.16, -86.52
# Status Code: 200
# Address found: 1108 East University Street, Bloomington, IN 47401, United States of America
# Requesting coordinates: 35.78, -78.11
# Status Code: 200
# Address found: 5984 Deans Street, Bailey, Nash County, NC 27807, United States of America
# Requesting coordinates: 35.19, -80.83
# Status Code: 200
# Address found: Queens Road, Charlotte, NC 28274, United States of America
# Requesting coordinates: 34.21, -119.18
# Status Code: 200
# Address found: 327 West Roderick Avenue, Oxnard, CA 93030, United States of America
# Requesting coordinates: 38.95, -76.95
# Status Code: 200
# Address found: Rachel Carson Greenway Trail, Hyattsville, MD 20722, United States of America
# Requesting coordinates: 35.97, -96.76
# Status Code: 200
# Address found: 908 East 11th Street, Cushing, OK 74023, United States of America
# Requesting coordinates: 43.37, -124.14
# Status Code: 200
# Address found: South Coos River Lane, Coos County, OR, United States of America
# Requesting coordinates: 34.05, -84.67
# Status Code: 200
# Address found: Golflinks Drive, Acworth, GA 30101, United States of America
# Requesting coordinates: 42.93, -75.38
# Status Code: 200
# Address found: Dollar General, 101 West Main Street, Village of Waterville, Oneida County, NY 13480, United States of America
# Requesting coordinates: 33.94, -83.99
# Status Code: 200
# Address found: 219 Pineview Drive, Lawrenceville, GA 30046, United States of America
# Requesting coordinates: 36.69, -84.47
# Status Code: 200
# Address found: Leroy McKee Road, Stearns, McCreary County, KY 42638, United States of America
# Requesting coordinates: 36.88, -94.87
# Status Code: 200
# Address found: 388 G Street Northeast, Miami, OK 74354, United States of America
# Requesting coordinates: 28.24, -81.28
# Status Code: 200
# Address found: Saint Cloud High School, Bulldog Lane, Saint Cloud, FL 34769, United States of America
# Requesting coordinates: 44.35, -89.07
# Status Code: 200
# Address found: 1200 Crystal Court, Waupaca, WI 54981, United States of America
# Requesting coordinates: 40.84, -73.87
# Status Code: 200
# Address found: 1610 Adams Street, New York, NY 10460, United States of America
# Requesting coordinates: 40.05, -86.03
# Status Code: 200
# Address found: Stayer Drive, Noblesville, IN 46062, United States of America
# Requesting coordinates: 37.2, -87.17
# Status Code: 200
# Address found: unnamed road, Greenville, Muhlenberg County, KY 42345, United States of America
# Requesting coordinates: 34.24, -84.49
# Status Code: 200
# Address found: First Methodist Episcopal Church South, North Street, Canton, GA 30114, United States of America
# Requesting coordinates: 27.75, -82.64
# Status Code: 200
# Address found: 18th Avenue South, Saint Petersburg, FL 33705, United States of America
# Requesting coordinates: 40.57, -112.33
# Status Code: 200
# Address found: Tooele, Utah, United States of America
# Requesting coordinates: 30.26, -97.74
# Status Code: 200
# Address found: El Zócalo, Austin, TX 78767, United States of America
# Requesting coordinates: 41.19, -85.7
# Status Code: 200
# Address found: East Ryerson Road, Pierceton, Kosciusko County, IN 46562, United States of America
# Requesting coordinates: 37.91, -122.01
# Status Code: 200
# Address found: Bowling Green Drive, Walnut Creek, CA 94598, United States of America
# Requesting coordinates: 41.7, -70.3
# Status Code: 200
# Address found: 1776 Hyannis Road, Barnstable, Barnstable County, MA 02630, United States of America
# Requesting coordinates: 36.3, -115.24
# Status Code: 200
# Address found: 6700 Royal Stallion Court, Las Vegas, NV 89131, United States of America
# Requesting coordinates: 44.53, -72.0
# Status Code: 200
# Address found: Charles Street, Lyndonville, Caledonia County, VT 05850, United States of America
# Requesting coordinates: 33.72, -84.42
# Status Code: 200
# Address found: 984 Cox Avenue Southwest, Atlanta, GA 30310, United States of America
# Requesting coordinates: 27.98, -80.66
# Status Code: 200
# Address found: 800 Carnation Avenue Southeast, Palm Bay, FL 32909, United States of America
# Requesting coordinates: 33.41, -96.57
# Status Code: 200
# Address found: 1535 South Waco Street, Van Alstyne, TX 75495, United States of America
# Requesting coordinates: 36.17, -86.78
# Status Code: 200
# Address found: 582 2nd Avenue North, Nashville-Davidson, TN 37201, United States of America
# Requesting coordinates: 34.42, -84.11
# Status Code: 200
# Address found: Dawson County Junior High, 109 Allen Street, Dawsonville, Dawson County, GA 30534, United States of America
# Requesting coordinates: 44.96, -93.26
# Status Code: 200
# Address found: 912 East 24th Street, Minneapolis, MN 55404, United States of America
# Requesting coordinates: 32.69, -97.01
# Status Code: 200
# Address found: 480 Brian Drive, Grand Prairie, TX 75052, United States of America
# Requesting coordinates: 41.66, -70.34
# Status Code: 200
# Address found: 16 Juniper Road, Centerville, Barnstable County, MA 02632, United States of America
# Requesting coordinates: 40.44, -86.91
# Status Code: 200
# Address found: 369 Highland Drive, West Lafayette, IN 47906, United States of America
# Requesting coordinates: 47.3, -122.37
# Status Code: 200
# Address found: 33619 28th Avenue Southwest, Federal Way, WA 98023, United States of America
# Requesting coordinates: 32.75, -97.33
# Status Code: 200
# Address found: AT&T Building, 1116 Houston Street, Fort Worth, TX 76102, United States of America
# Requesting coordinates: 40.63, -82.96
# Status Code: 200
# Address found: Caledonia-Climax Road, Claridon Township, OH 43314, United States of America
# Requesting coordinates: 33.44, -111.8
# Status Code: 200
# Address found: 1333 North Barkley, Mesa, AZ 85203, United States of America
# Requesting coordinates: 42.41, -71.16
# Status Code: 200
# Address found: 61 Norfolk Road, Arlington, MA 02174, United States of America
# Requesting coordinates: 40.84, -73.4
# Status Code: 200
# Address found: 263 Depot Road, Huntington Station, NY 11746, United States of America
# Requesting coordinates: 40.32, -80.21
# Status Code: 200
# Address found: C & C Self Storage, 90 Cowden Road, McDonald, Cecil, PA 15057, United States of America
# Requesting coordinates: 35.32, -82.46
# Status Code: 200
# Address found: 714 North King Street, Hendersonville, NC 28792, United States of America
# Requesting coordinates: 41.23, -80.81
# Status Code: 200
# Address found: Diane Sauer Chevrolet, Niles Road Southeast, Warren, OH 44482, United States of America
# Requesting coordinates: 36.12, -95.91
# Status Code: 200
# Address found: 3092 South Irvington Avenue, Tulsa, OK 74114, United States of America
# Requesting coordinates: 39.04, -76.49
# Status Code: 200
# Address found: Freshfields Lane, Foxmoor, Arnold, MD 21012, United States of America
# Requesting coordinates: 40.11, -83.13
# Status Code: 200
# Address found: Coffman High School Campus, Coffman Road, Dublin, OH 43016, United States of America
# Requesting coordinates: 35.44, -94.35
# Status Code: 200
# Address found: 991 William Penn Street, Van Buren, AR 72956, United States of America
# Requesting coordinates: 45.19, -123.24
# Status Code: 200
# Address found: Southwest Peavine Road, Yamhill County, OR, United States of America
# Requesting coordinates: 27.75, -82.64
# Status Code: 200
# Address found: 18th Avenue South, Saint Petersburg, FL 33705, United States of America
# Requesting coordinates: 40.6, -74.76
# Status Code: 200
# Address found: Willocks Court, Readington Township, NJ 08889, United States of America
# Requesting coordinates: 47.67, -122.18
# Status Code: 200
# Address found: 12005 Northeast 73rd Street, Rose Hill, Kirkland, WA 98033, United States of America
# Requesting coordinates: 42.27, -83.73
# Status Code: 200
# Address found: 1430 Cambridge Road, Ann Arbor, MI 48104, United States of America
# Requesting coordinates: 41.88, -87.97
# Status Code: 200
# Address found: 544 South Villa Avenue, Villa Park, IL 60181, United States of America
# Requesting coordinates: 36.01, -82.15
# Status Code: 200
# Address found: Cane Creek Road, Clarrissa, Mitchell County, NC 28705, United States of America
# Requesting coordinates: 41.15, -85.48
# Status Code: 200
# Address found: 512 East Hanna Street, Columbia City, IN 46725, United States of America
# Requesting coordinates: 38.76, -89.97
# Status Code: 200
# Address found: East Ingle Drive, Glen Carbon, IL 62034, United States of America
# Requesting coordinates: 27.75, -82.64
# Status Code: 200
# Address found: 18th Avenue South, Saint Petersburg, FL 33705, United States of America
# Requesting coordinates: 39.87, -75.92
# Status Code: 200
# Address found: East Praecipe Way, West Fallowfield Township, PA 19330, United States of America
# Requesting coordinates: 41.83, -87.68
# Status Code: 200
# Address found: South Leavitt Street, Chicago, IL 60608, United States of America
# Requesting coordinates: 40.81, -81.93
# Status Code: 200
# Address found: College of Wooster, 1189 Beall Avenue, Wooster, OH 44691, United States of America
# Requesting coordinates: 42.63, -71.32
# Status Code: 200
# Address found: Abraham Lincoln Elementary School, 300 Chelmsford Street, Ayres City, Lowell, MA 01851, United States of America
# Requesting coordinates: 37.96, -76.51
# Status Code: 200
# Address found: Lake Road, Lottsburg, Northumberland County, VA 22511, United States of America
# Requesting coordinates: 40.66, -73.7
# Status Code: 200
# Address found: 305 Rockaway Avenue, Village of Valley Stream, NY 11580, United States of America
# Requesting coordinates: 42.76, -78.74
# Status Code: 200
# Address found: 133 Highland Avenue, Village of Orchard Park, Erie County, NY 14127, United States of America
# Requesting coordinates: 42.27, -89.06
# Status Code: 200
# Address found: 358 Rome Avenue, Rockford, IL 61107, United States of America
# Requesting coordinates: 39.12, -97.7
# Status Code: 200
# Address found: 138 South 1st Avenue, Minneapolis, KS 67467, United States of America
# Requesting coordinates: 32.75, -97.33
# Status Code: 200
# Address found: AT&T Building, 1116 Houston Street, Fort Worth, TX 76102, United States of America
# Requesting coordinates: 41.83, -87.68
# Status Code: 200
# Address found: South Leavitt Street, Chicago, IL 60608, United States of America
# Requesting coordinates: 39.16, -89.48
# Status Code: 200
# Address found: Brailly Road, Hillsboro, IL 62049, United States of America
# Requesting coordinates: 32.91, -96.62
# Status Code: 200
# Address found: 950 Lister Drive, Garland, TX 75040, United States of America
# Requesting coordinates: 35.14, -96.49
# Status Code: 200
# Address found: 1836 Redbud Street, Wewoka, OK 74884, United States of America
# Requesting coordinates: 41.56, -70.55
# Status Code: 200
# Address found: 333 Central Avenue, Menauhant, Falmouth, MA 02536, United States of America
# Requesting coordinates: 41.8, -91.49
# Status Code: 200
# Address found: Lite Window & Door, Windflower Lane, Solon, IA 52333, United States of America
# Requesting coordinates: 39.77, -86.14
# Status Code: 200
# Address found: 211 Dickson Street, Indianapolis, IN 46202, United States of America
# Requesting coordinates: 34.14, -118.46
# Status Code: 200
# Address found: 3819 Stone Canyon Avenue, Los Angeles, CA 91403, United States of America
# Requesting coordinates: 32.35, -86.28
# Status Code: 200
# Address found: Montgomery Country Club, Woodley Road, Wildwood, Montgomery, AL 36116, United States of America
# Requesting coordinates: 33.14, -95.95
# Status Code: 200
# Address found: Morris, Campbell, Hunt County, TX 75422, United States of America
# Requesting coordinates: 30.44, -87.18
# Status Code: 200
# Address found: Hyde Park Road, Pensacola, FL 32503, United States of America
# Requesting coordinates: 33.71, -84.53
# Status Code: 200
# Address found: 1775 Niskey Lake Trail Southwest, Atlanta, GA 30331, United States of America
# Requesting coordinates: 38.06, -78.9
# Status Code: 200
# Address found: 783 Rife Road, Waynesboro, VA 22980, United States of America
# Requesting coordinates: 41.83, -87.68
# Status Code: 200
# Address found: South Leavitt Street, Chicago, IL 60608, United States of America
# Requesting coordinates: 42.47, -70.96
# Status Code: 200
# Address found: Lynn Medical and Office Building, 225 Boston Street, Lynn, MA 01904, United States of America
# Requesting coordinates: 33.86, -84.68
# Status Code: 200
# Address found: 3857 North Avenue, Powder Springs, GA 30127, United States of America
# Requesting coordinates: 35.46, -97.51
# Status Code: 200
# Address found: South Walnut Avenue, Oklahoma City, OK 73129, United States of America
# Requesting coordinates: 33.92, -118.2
# Status Code: 200
# Address found: Century Freeway, Lynwood, CA 90262, United States of America
# Requesting coordinates: 36.1, -115.02
# Status Code: 200
# Address found: Overlook Way, Whitney, NV 89112, United States of America
# Requesting coordinates: 34.83, -82.37
# Status Code: 200
# Address found: Pita House, 495 South Pleasantburg Drive, Cavalier Heights, Greenville, SC 29607, United States of America
# Requesting coordinates: 36.81, -119.75
# Status Code: 200
# Address found: unnamed road, Fresno, CA 93740, United States of America
# Requesting coordinates: 29.7, -98.11
# Status Code: 200
# Address found: Comanche Street, New Braunfels, TX 78130, United States of America
# Requesting coordinates: 42.61, -94.14
# Status Code: 200
# Address found: unnamed road, Badger, Badger Township, IA 50516, United States of America
# Requesting coordinates: 41.87, -88.01
# Status Code: 200
# Address found: 325 Circle Avenue, Lombard, IL 60148, United States of America
# Requesting coordinates: 34.43, -119.68
# Status Code: 200
# Address found: 410 North Cañada Street, Santa Barbara, CA 93103, United States of America
# Requesting coordinates: 42.78, -72.48
# Status Code: 200
# Address found: 61 Tower Hill Road, Hinsdale, Cheshire County, NH 03451, United States of America
# Requesting coordinates: 37.89, -85.96
# Status Code: 200
# Address found: Lindsey Golf Course, 4024 Bullion Boulevard, Gaffey Heights, Hardin County, KY 40121, United States of America
# Requesting coordinates: 36.34, -79.67
# Status Code: 200
# Address found: Pennrose Park Country Club, 1622 Country Club Road, Reidsville, NC 27323, United States of America
# Requesting coordinates: 44.45, -95.78
# Status Code: 200
# Address found: True Light Christian School, 600 East College Drive, Marshall, MN 56258, United States of America
# Requesting coordinates: 47.11, -122.76
# Status Code: 200
# Address found: Waldron Drive Northeast, Lacey, WA 98561, United States of America
# Requesting coordinates: 41.83, -87.68
# Status Code: 200
# Address found: South Leavitt Street, Chicago, IL 60608, United States of America
# Requesting coordinates: 44.02, -72.23
# Status Code: 200
# Address found: Goose Green Road, South Corinth, Corinth, VT 05033, United States of America
# Requesting coordinates: 31.84, -106.43
# Status Code: 200
# Address found: Underwood Golf Complex, Ellerthorpe Avenue, El Paso, TX 79904, United States of America
# Requesting coordinates: 47.83, -122.32
# Status Code: 200
# Address found: 18616 64th Avenue West, Lynnwood, WA 98037, United States of America
# Requesting coordinates: 43.97, -75.91
# Status Code: 200
# Address found: 135 Keyes Avenue, City of Watertown, NY 13601, United States of America
# Requesting coordinates: 39.14, -76.77
# Status Code: 200
# Address found: Oak Ridge Road, Jessup, Anne Arundel County, MD 20701, United States of America
# Requesting coordinates: 32.34, -108.7
# Status Code: 200
# Address found: Airport Road, Lordsburg, NM 88045, United States of America
# Requesting coordinates: 42.38, -76.39
# Status Code: 200
# Address found: 35 White Church Road, Brooktondale, Tompkins County, NY 14817, United States of America
# Requesting coordinates: 41.97, -91.66
# Status Code: 200
# Address found: 2nd Street Southeast, Cedar Rapids, IA 52401, United States of America
# Requesting coordinates: 38.78, -121.37
# Status Code: 200
# Address found: 2209 Lockton Drive, Roseville, CA 95747, United States of America
# Requesting coordinates: 34.72, -92.35
# Status Code: 200
# Address found: 3601 South Bryant Street, Little Rock, AR 72204, United States of America
# Requesting coordinates: 40.71, -74.06
# Status Code: 200
# Address found: 14 Monitor Street, Communipaw, Jersey City, NJ 07304, United States of America
# Requesting coordinates: 38.86, -104.76
# Status Code: 200
# Address found: 1911 Berkshire Lane, Colorado Springs, CO 80909, United States of America
# Requesting coordinates: 39.0, -77.4
# Status Code: 200
# Address found: 414 East Furman Drive, Sterling, VA 20164, United States of America
# Requesting coordinates: 41.57, -93.61
# Status Code: 200
# Address found: 354 Hartford Avenue, Des Moines, IA 50315, United States of America
# Requesting coordinates: 44.44, -69.83
# Status Code: 200
# Address found: Snowmobile Trail 29A, Belgrade, Kennebec County, ME 04917, United States of America
# Requesting coordinates: 32.79, -117.25
# Status Code: 200
# Address found: 4000 Bayside Walk, San Diego, CA 92109, United States of America
# Requesting coordinates: 35.57, -82.54
# Status Code: 200
# Address found: 73 Swannanoa River Road, Asheville, NC 28805, United States of America
# Requesting coordinates: 36.16, -115.28
# Status Code: 200
# Address found: 1050 South Durango Drive, Las Vegas, NV 89145, United States of America
# Requesting coordinates: 37.3, -121.8
# Status Code: 200
# Address found: 3881 Ashridge Lane, San Jose, CA 95121, United States of America
# Requesting coordinates: 26.23, -80.13
# Status Code: 200
# Address found: 380 Southwest 1st Court, Pompano Beach, FL 33060, United States of America
# Requesting coordinates: 40.26, -80.18
# Status Code: 200
# Address found: 102 Adams Avenue, Canonsburg, PA 15317, United States of America
# Requesting coordinates: 34.28, -118.44
# Status Code: 200
# Address found: 310 Chatsworth Drive, San Fernando, CA 91340, United States of America
# Requesting coordinates: 45.34, -122.66
# Status Code: 200
# Address found: 1356 Jay Court, West Linn, OR 97068, United States of America
# Requesting coordinates: 42.25, -71.9
# Status Code: 200
# Address found: 28 Deer Pond Drive, Leicester, Worcester County, MA 01524, United States of America
# Requesting coordinates: 35.33, -89.88
# Status Code: 200
# Address found: Wasp Avenue, Millington, TN 38054, United States of America
# Requesting coordinates: 41.47, -81.85
# Status Code: 200
# Address found: Westway Drive, Rocky River, OH 44116, United States of America
# Requesting coordinates: 42.29, -85.22
# Status Code: 200
# Address found: 138 Pepperidge Lane, Battle Creek, MI 49015, United States of America
# Requesting coordinates: 42.66, -83.38
# Status Code: 200
# Address found: 4657 Claudia Drive, Waterford Township, MI 48328, United States of America
# Requesting coordinates: 34.2, -86.15
# Status Code: 200
# Address found: Kilpatrick Road, Boaz, AL 35957, United States of America
# Requesting coordinates: 39.09, -84.51
# Status Code: 200
# Address found: East RiverCenter Boulevard, Covington, KY 41011, United States of America
# Requesting coordinates: 35.11, -106.62
# Status Code: 200
# Address found: 2213 Woodland Avenue Northeast, Albuquerque, NM 87107, United States of America
# Requesting coordinates: 40.86, -76.78
# Status Code: 200
# Address found: Beegle Street, Sunbury, PA 17801, United States of America
# Requesting coordinates: 35.48, -120.92
# Status Code: 200
# Address found: 833 Picachio Road, San Luis Obispo County, CA 93430, United States of America
# Requesting coordinates: 30.58, -84.58
# Status Code: 200
# Address found: Carter-Parramore Academy, 631 South Stewart Street, Quincy, FL 32351, United States of America
# Requesting coordinates: 36.18, -82.07
# Status Code: 200
# Address found: Frank Birchfield Road, Roan Mountain, Carter County, TN 37687, United States of America
# Requesting coordinates: 40.43, -79.97
# Status Code: 200
# Address found: River Park Commons, 2403 Sidney Street, Pittsburgh, PA 15203, United States of America
# Requesting coordinates: 35.13, -112.99
# Status Code: 200
# Address found: Forest Service Road 9801A, Yavapai County, AZ, United States of America
# Requesting coordinates: 36.15, -85.5
# Status Code: 200
# Address found: Commerce Avenue, Capshaw Woods, Cookeville, TN 38503, United States of America
# Requesting coordinates: 26.14, -80.13
# Status Code: 200
# Address found: 1157 Northeast 14th Avenue, Fort Lauderdale, FL 33304, United States of America
# Requesting coordinates: 45.47, -122.37
# Status Code: 200
# Address found: 7234 Southeast 282nd Avenue, Gresham, OR 97080, United States of America
# Requesting coordinates: 31.13, -93.27
# Status Code: 200
# Address found: 1456 South 10th Street, Dixie, Leesville, LA 71446, United States of America
# Requesting coordinates: 40.75, -103.06
# Status Code: 200
# Address found: County Road 55, Logan County, CO 80736, United States of America
# Requesting coordinates: 35.87, -96.05
# Status Code: 200
# Address found: West 201st Street South, Mounds, Creek County, OK 74047, United States of America
# Requesting coordinates: 38.66, -121.62
# Status Code: 200
# Address found: 18973 County Road 122, Kiesel, Yolo County, CA 95691, United States of America
# Requesting coordinates: 41.01, -73.84
# Status Code: 200
# Address found: 16 Western Drive, Village of Ardsley, NY 10502, United States of America
# Requesting coordinates: 30.42, -86.61
# Status Code: 200
# Address found: Law Firm of Cameron D Simpson PA, 150 Eglin Parkway Northeast, Cinco Bayou, Fort Walton Beach, FL 32548, United States of America
# Requesting coordinates: 34.47, -86.8
# Status Code: 200
# Address found: 111 High Street, Somerville, Morgan County, AL 35670, United States of America
# Requesting coordinates: 48.28, -122.62
# Status Code: 200
# Address found: Tower Road, Oak Harbor, WA 97277, United States of America
# Requesting coordinates: 38.02, -121.3
# Status Code: 200
# Address found: 1120 East Hammer Lane, Stockton, CA 95296, United States of America
# Requesting coordinates: 26.14, -80.13
# Status Code: 200
# Address found: 1157 Northeast 14th Avenue, Fort Lauderdale, FL 33304, United States of America
# Requesting coordinates: 39.92, -77.8
# Status Code: 200
# Address found: unnamed road, Saint Thomas, St. Thomas Township, PA 17252, United States of America
# Requesting coordinates: 32.07, -110.92
# Status Code: 200
# Address found: East Old Vail Connection Road, Tucson, AZ 85766, United States of America
# Requesting coordinates: 41.64, -88.44
# Status Code: 200
# Address found: 328 East Van Emmon Street, Yorkville, IL 60560, United States of America
# Requesting coordinates: 45.54, -122.64
# Status Code: 200
# Address found: 2414 Northeast 25th Avenue, Portland, OR 97212, United States of America
# Requesting coordinates: 42.37, -83.46
# Status Code: 200
# Address found: Carson's Barber Shop, 427 Lilley Road, Plymouth, Wayne County, MI 48170, United States of America
# Requesting coordinates: 37.74, -122.44
# Status Code: 200
# Address found: 209 Berkeley Way, San Francisco, CA 94131, United States of America
# Requesting coordinates: 31.49, -97.23
# Status Code: 200
# Address found: 13003 Bent Oak Drive, Woodway, McLennan County, TX 76712, United States of America
# Requesting coordinates: 46.87, -96.81
# Status Code: 200
# Address found: 1783 5th Avenue South, Fargo, ND 58103, United States of America
# Requesting coordinates: 28.2, -82.59
# Status Code: 200
# Address found: Cannon Drive, Starkey Ranch, FL 34656, United States of America
# Requesting coordinates: 40.13, -75.06
# Status Code: 200
# Address found: 2770 Buck Road, Bryn Athyn, Montgomery County, PA 19009, United States of America
# Requesting coordinates: 30.06, -89.93
# Status Code: 200
# Address found: Michoud Boulevard, Village de L’Est, New Orleans, LA 70129, United States of America
# Requesting coordinates: 33.95, -118.29
# Status Code: 200
# Address found: 826 West 95th Street, Los Angeles, CA 90044, United States of America
# Requesting coordinates: 43.0, -78.87
# Status Code: 200
# Address found: 136 Bannard Avenue, City of Tonawanda, NY 14150, United States of America
# Requesting coordinates: 32.32, -90.2
# Status Code: 200
# Address found: 699 Erie Street, Jackson, MS 39203, United States of America
# Requesting coordinates: 31.44, -93.45
# Status Code: 200
# Address found: Plainview Road, Florien, Sabine Parish, LA, United States of America
# Requesting coordinates: 47.36, -122.1
# Status Code: 200
# Address found: MultiCare Covington Medical Center, 17700 Southeast 272nd Street, Covington, WA 98042, United States of America
# Requesting coordinates: 42.35, -71.22
# Status Code: 200
# Address found: 25 Armory Street, Newton, MA 02465, United States of America
# Requesting coordinates: 29.76, -95.38
# Status Code: 200
# Address found: 1701 Bluebonnet Place Circle, Houston, TX 77019, United States of America
# Requesting coordinates: 44.65, -93.17
# Status Code: 200
# Address found: unnamed road, Farmington, MN 55024, United States of America
# Requesting coordinates: 30.21, -93.2
# Status Code: 200
# Address found: 2332 Aster Street, Lake Charles, LA 70601, United States of America
# Requesting coordinates: 41.41, -82.31
# Status Code: 200
# Address found: Brownhelm Station Road, Vermilion, OH 44089, United States of America
# Requesting coordinates: 43.08, -76.37
# Status Code: 200
# ...
# Requesting coordinates: 41.15, -81.24
# Status Code: 200
# Address found: 637 South Walnut Street, Ravenna, OH 44266, United States of America
# Requesting coordinates: 20.88, -156.5
# Status Code: 200
# Address found: 499 Waiale Road, Wailuku, HI 96793, United States of America
# Requesting coordinates: 37.92, -122.34
# Status Code: 200
# Address found: John T. Knox Freeway, Richmond, CA 94804, United States of America
# Requesting coordinates: 38.44, -121.3
# Status Code: 200
# Address found: 8800 Chambray Road, Elk Grove, CA 95624, United States of America
# Requesting coordinates: 31.07, -83.19
# Status Code: 200
# Address found: Johnson Street, Ray City, Berrien County, GA, United States of America
# Requesting coordinates: 28.82, -96.98
# Status Code: 200
# Address found: 2433 Bon Aire Avenue, Victoria, TX 77901, United States of America
# Requesting coordinates: 42.93, -75.46
# Status Code: 200
# Address found: 4321 Camp Road, Madison, Madison County, NY 13425, United States of America
# Requesting coordinates: 35.19, -80.83
# Status Code: 200
# Address found: Queens Road, Charlotte, NC 28274, United States of America
# Requesting coordinates: 38.91, -75.43
# Status Code: 200
# Address found: 75 South Maple Avenue, Milford, DE 19963, United States of America
# Requesting coordinates: 42.24, -83.18
# Status Code: 200
# Address found: 3115 Fort Street, Lincoln Park, MI 48146, United States of America
# Requesting coordinates: 28.3, -81.41
# Status Code: 200
# Address found: Osceola Regional Medical Center, 700 West Oak Street, Kissimmee, FL 34741, United States of America
# Requesting coordinates: 34.08, -117.46
# Status Code: 200
# Address found: 9568 Almeria Court, Fontana, CA 92335, United States of America
# Requesting coordinates: 38.87, -82.99
# Status Code: 200
# Address found: Broad Street, Lucasville, Scioto County, OH 45648, United States of America
# Requesting coordinates: 41.7, -111.87
# Status Code: 200
# Address found: 1432 1800 South, Logan, UT 84321, United States of America
# Requesting coordinates: 40.85, -74.1
# Status Code: 200
# Address found: Alden Street, Wallington, NJ 07057, United States of America
# Requesting coordinates: 40.79, -90.16
# Status Code: 200
# Address found: 501 IL 97, Maquon, Knox County, IL 61458, United States of America
# Requesting coordinates: 26.45, -80.08
# Status Code: 200
# Address found: 793 Southwest 7th Avenue, Delray Beach, FL 33444, United States of America
# Requesting coordinates: 47.79, -122.2
# Status Code: 200
# Address found: 23010 27th Avenue Southeast, Bothell, WA 98021, United States of America
# Requesting coordinates: 34.02, -118.28
# Status Code: 200
# Address found: Galen Center, West Jefferson Boulevard, Los Angeles, CA 90089, United States of America
# Requesting coordinates: 44.99, -91.72
# Status Code: 200
# Address found: 860th Avenue, Colfax, Colfax, WI 54730, United States of America
# Requesting coordinates: 27.8, -97.39
# Status Code: 200
# Address found: Corpus Christi Marina, 400A North Shoreline Boulevard, Corpus Christi, TX 78401, United States of America
# Requesting coordinates: 31.62, -82.88
# Status Code: 200
# Address found: 37 Broxton-West Green Highway, Broxton, Coffee County, GA 31519, United States of America
# Requesting coordinates: 38.22, -85.74
# Status Code: 200
# Address found: 1126 Forrest Street, Germantown, Louisville, KY 40217, United States of America
# Requesting coordinates: 41.24, -73.31
# Status Code: 200
# Address found: 436 Westport Road, Easton, Greater Bridgeport Planning Region, CT 06612, United States of America
# Requesting coordinates: 31.06, -98.18
# Status Code: 200
# Address found: National United Bank, 101 East 9th Street, Lampasas, TX 76550, United States of America
# Requesting coordinates: 35.4, -80.59
# Status Code: 200
# Address found: Glen Rae Street Southwest, Concord, NC 28026, United States of America
# Requesting coordinates: 27.98, -80.66
# Status Code: 200
# Address found: 800 Carnation Avenue Southeast, Palm Bay, FL 32909, United States of America
# Requesting coordinates: 40.68, -73.37
# Status Code: 200
# Address found: 435 South 3rd Street, Village of Lindenhurst, NY 11757, United States of America
# Requesting coordinates: 44.37, -73.4
# Status Code: 200
# Address found: 3943 Station Road, Willsboro, Essex County, NY 12996, United States of America
# Requesting coordinates: 37.97, -122.5
# Status Code: 200
# Address found: Point San Pedro Road, Country Club, San Rafael, CA 94911, United States of America
# Requesting coordinates: 47.91, -97.07
# Status Code: 200
# Address found: Altru Hospital, 1200 South Columbia Road, Grand Forks, ND 58201, United States of America
# Requesting coordinates: 38.93, -121.25
# Status Code: 200
# Address found: Madeira Island Lane, Placer County, CA, United States of America
# Requesting coordinates: 46.04, -95.29
# Status Code: 200
# Address found: Miltona Carlos Road Northeast, Douglas County, MN 56319, United States of America
# Requesting coordinates: 34.93, -79.76
# Status Code: 200
# Address found: Sherwin-Williams, Broad Avenue, East Rockingham, Rockingham, NC 28379, United States of America
# Requesting coordinates: 33.44, -79.56
# Status Code: 200
# Address found: 298 East Tamarack Street, Andrews, SC 29510, United States of America
# Requesting coordinates: 27.95, -82.48
# Status Code: 200
# Address found: 2015 West Cass Street, Tampa, FL 33606, United States of America
# Requesting coordinates: 35.46, -86.08
# Status Code: 200
# Address found: Hamilton Court, Manchester, TN 37389, United States of America
# Requesting coordinates: 33.99, -117.53
# Status Code: 200
# Address found: 5363 Rigel Way, Jurupa Valley, CA 91752, United States of America
# Requesting coordinates: 38.81, -76.75
# Status Code: 200
# Address found: Prince George’s Equestrian Center Show Ring, Water Street, Upper Marlboro, MD 20792, United States of America
# Requesting coordinates: 47.49, -122.1
# Status Code: 200
# Address found: 17919 Southeast 123rd Place, Renton, WA 98059, United States of America
# Requesting coordinates: 33.15, -117.17
# Status Code: 200
# Address found: 800 Palo Alto Court, San Marcos, CA 92096, United States of America
# Requesting coordinates: 35.55, -117.67
# Status Code: 200
# Address found: College Heights Boulevard (RC10), Kern County, CA, United States of America
# Requesting coordinates: 33.73, -117.05
# Status Code: 200
# Address found: 26950 California Avenue, Winchester, Riverside County, CA 92545, United States of America
# Requesting coordinates: 36.56, -82.19
# Status Code: 200
# Address found: Wonder Valley Road, Belle Brook Estates, Bristol, TN 37620, United States of America
# Requesting coordinates: 38.61, -88.78
# Status Code: 200
# Address found: Hesser Road, Iuka Township, IL 62849, United States of America
# Requesting coordinates: 36.6, -119.75
# Status Code: 200
# Address found: 9400 South Chance Avenue, Bowles, Fresno County, CA 93725, United States of America
# Requesting coordinates: 36.33, -82.36
# Status Code: 200
# Address found: James H. Quillen Parkway, Montcastle Hills, Johnson City, TN 37605, United States of America
# Requesting coordinates: 34.06, -117.79
# Status Code: 200
# Address found: Humane Way, Pomona, CA 91768, United States of America
# Requesting coordinates: 38.01, -121.38
# Status Code: 200
# Address found: West Rindge Road, San Joaquin County, CA 95219, United States of America
# Requesting coordinates: 43.04, -76.14
# Status Code: 200
# Address found: 788 Irving Avenue, City of Syracuse, NY 13210, United States of America
# Requesting coordinates: 35.73, -77.92
# Status Code: 200
# Address found: 757 Franklin Avenue West, Wilson, NC 27893, United States of America
# Requesting coordinates: 40.98, -74.11
# Status Code: 200
# Address found: 322 Marshall Street, Ridgewood, NJ 07450, United States of America
# Requesting coordinates: 35.48, -96.89
# Status Code: 200
# Address found: Bankers Hill Road, Meeker, Lincoln County, OK 74855, United States of America
# Requesting coordinates: 34.98, -80.54
# Status Code: 200
# Address found: 482 East Franklin Street, Roland Park, Monroe, NC 28112, United States of America
# Requesting coordinates: 41.26, -96.01
# Status Code: 200
# Address found: 6334 Dodge Street, Omaha, NE 68132, United States of America
# Requesting coordinates: 44.21, -88.43
# Status Code: 200
# Address found: 926 Marquette Street, Brighton Beach, Menasha, WI 54952, United States of America
# Requesting coordinates: 29.76, -95.38
# Status Code: 200
# Address found: 1701 Bluebonnet Place Circle, Houston, TX 77019, United States of America
# Requesting coordinates: 41.44, -74.42
# Status Code: 200
# Address found: 92 Academy Avenue, City of Middletown, NY 10940, United States of America
# Requesting coordinates: 38.01, -121.38
# Status Code: 200
# Address found: West Rindge Road, San Joaquin County, CA 95219, United States of America
# Requesting coordinates: 41.51, -93.48
# Status Code: 200
# Address found: Southeast 64th Street, Carlisle, IA 50047, United States of America
# Requesting coordinates: 40.24, -76.92
# Status Code: 200
# Address found: Mid Penn Bank, 2148 Market Street, Camp Hill, Cumberland County, PA 17011, United States of America
# Requesting coordinates: 42.39, -113.78
# Status Code: 200
# Address found: East 1000 South, Cassia County, ID, United States of America
# Requesting coordinates: 27.9, -82.78
# Status Code: 200
# Address found: Jack Oak Drive, Pinellas County, FL 34649, United States of America
# Requesting coordinates: 41.38, -81.64
# Status Code: 200
# Address found: Independence Historical Society, Public Square, Independence, OH 44131, United States of America
# Requesting coordinates: 40.0, -75.26
# Status Code: 200
# Address found: 115 Glenwood Road, Lower Merion Township, PA 19066, United States of America
# Requesting coordinates: 39.64, -84.08
# Status Code: 200
# Address found: 2058 Cabernet Way, Bellbrook, Greene County, OH 45305, United States of America
# Requesting coordinates: 33.37, -84.78
# Status Code: 200
# Address found: East Broad Street, Newnan, GA 30263, United States of America
# Requesting coordinates: 33.79, -82.47
# Status Code: 200
# Address found: Elm Avenue, Lincolnton, Lincoln County, GA 30817, United States of America
# Requesting coordinates: 39.69, -76.06
# Status Code: 200
# Address found: 222 Biggs Highway, Rising Sun, Cecil County, MD 21911, United States of America
# Requesting coordinates: 30.65, -93.89
# Status Code: 200
# Address found: East Pine Street, Kirbyville, Jasper County, TX 75956, United States of America
# Requesting coordinates: 36.67, -76.3
# Status Code: 200
# Address found: unnamed road, Chesapeake, VA 23327, United States of America
# Requesting coordinates: 38.35, -81.63
# Status Code: 200
# Address found: Motel 6 Charleston Civic Center, Spurlock Alley, Charleston, WV 25301, United States of America
# Requesting coordinates: 33.82, -117.91
# Status Code: 200
# Address found: Anaheim Global Medical Center, 1025 South Anaheim Boulevard, Anaheim, CA 92805, United States of America
# Requesting coordinates: 27.92, -97.29
# Status Code: 200
# Address found: 246 Dogwood Street, Gregory, San Patricio County, TX 78359, United States of America
# Requesting coordinates: 39.3, -76.61
# Status Code: 200
# Address found: Maryland Metropolitan Transition Center, 954 Forrest Street, Baltimore, MD 21202, United States of America
# Requesting coordinates: 35.4, -93.11
# Status Code: 200
# Address found: unnamed road, Dover, Pope County, AR 72837, United States of America
# Requesting coordinates: 35.06, -85.25
# Status Code: 200
# Address found: 2176 Museum Street, East Chattanooga, Chattanooga, TN 37406, United States of America
# Requesting coordinates: 34.87, -85.5
# Status Code: 200
# Address found: Glenview Drive, Trenton, Dade County, GA 30752, United States of America
# Requesting coordinates: 33.0, -97.23
# Status Code: 200
# Address found: South Front Street, Roanoke, TX 76226, United States of America
# Requesting coordinates: 45.99, -84.36
# Status Code: 200
# Address found: South Islington Road, Clark Township, Mackinac County, MI 49719, United States of America
# Requesting coordinates: 41.76, -70.08
# Status Code: 200
# Address found: 2022 Main Street, East Brewster, Brewster, MA 02631, United States of America
# Requesting coordinates: 27.64, -80.39
# Status Code: 200
# Address found: 808 21st Street, Vero Beach, FL 32960, United States of America
# Requesting coordinates: 32.61, -93.28
# Status Code: 200
# Address found: 114 Joel Street, Minden, LA 71055, United States of America
# Requesting coordinates: 39.98, -82.98
# Status Code: 200
# Address found: 698 St Clair Avenue, Columbus, OH 43201, United States of America
# Requesting coordinates: 34.97, -89.99
# Status Code: 200
# Address found: 7599 Airways Boulevard, Southaven, MS 38671, United States of America
# Requesting coordinates: 35.97, -83.94
# Status Code: 200
# Address found: 1584 Exeter Avenue, Knoxville, TN 37921, United States of America
# Requesting coordinates: 41.62, -87.72
# Status Code: 200
# Address found: 14963 Terrace Lane, Midlothian, Bremen Township, IL 60445, United States of America
# Requesting coordinates: 33.62, -112.13
# Status Code: 200
# Address found: Desert Foothills Jr High School, West Saint Moritz Lane, Phoenix, AZ 85053, United States of America
# Requesting coordinates: 40.26, -81.84
# Status Code: 200
# Address found: Severn Drive, Coshocton, OH 43812, United States of America
# Requesting coordinates: 32.36, -92.97
# Status Code: 200
# Address found: Oak Street, Bienville, Bienville Parish, LA, United States of America
# Requesting coordinates: 46.21, -119.16
# Status Code: 200
# Address found: West Kennewick Avenue, Kennewick, WA 99336, United States of America
# Requesting coordinates: 36.52, -119.39
# Status Code: 200
# Address found: Avenue 400, Tulare County, CA 93666, United States of America
# Requesting coordinates: 33.69, -78.89
# Status Code: 200
# Address found: 675 4th Avenue North, Myrtle Beach, SC 29577, United States of America
# Requesting coordinates: 38.47, -90.75
# Status Code: 200
# Address found: 873 Jefferson Street, Pacific, MO 63069, United States of America
# Requesting coordinates: 40.65, -73.58
# Status Code: 200
# Address found: 34 Pierrepont Street, Village of Freeport, NY 11520, United States of America
# Requesting coordinates: 38.95, -84.54
# Status Code: 200
# Address found: 57 McKim Drive, Independence, KY 41051, United States of America
# Requesting coordinates: 40.66, -74.19
# Status Code: 200
# Address found: 530 Trumbull Street, Union Square, Elizabeth, NJ 07206, United States of America
# Requesting coordinates: 40.24, -76.92
# Status Code: 200
# Address found: Mid Penn Bank, 2148 Market Street, Camp Hill, Cumberland County, PA 17011, United States of America
# Requesting coordinates: 42.86, -71.48
# Status Code: 200
# Address found: Passaconaway Country Club, Waterview Circle, Litchfield, Hillsborough County, NH 03052, United States of America
#     client_id  current_age  birth_year  birth_month  gender  \
# 0         825           53        1966           11  Female
# 5        1746           53        1966           12  Female
# 10       1718           81        1938           11  Female
# 15        708           63        1957            1  Female
# 19       1164           43        1976            9    Male
#
#                                               address  latitude  longitude  \
# 0   7481 Brydon Road, La Verne, CA 91750, United S...     34.15    -117.76
# 5   51-17 Redfield Street, New York, NY 11362, Uni...     40.76     -73.74
# 10  Nogales Street, West Covina, CA 91792, United ...     34.02    -117.89
# 15  Market Slip, New York, NY 10002, United States...     40.71     -73.99
# 19  24;26 Caselli Avenue, San Francisco, CA 94114,...     37.76    -122.44
#
#     per_capita_income  yearly_income  total_debt  credit_score  \
# 0               29278          59696      127613           787
# 5               37891          77254      191349           701
# 10              22681          33483         196           698
# 15             163145         249925      202328           722
# 19              53797         109687      183855           675
#
#     num_credit_cards  debt_to_income
# 0                  5        2.137714
# 5                  5        2.476881
# 10                 5        0.005854
# 15                 4        0.809555
# 19                 1        1.676179

# %%
# Save the full DataFrame to a new CSV file
df2.to_csv('geocode_dataframe.csv', index=False)

# %%
import re

# Create new dataframe
df3 = df2.copy()

# Define a pattern for state and zip code
address_pattern = r'(\w{2}) (\d{5})'

# Add a comma after the state abbreviation and before the zip code
def add_comma(address):
    # Search for the pattern of the state and zip code
    match = re.search(address_pattern, address)
    if match:
        # If a match is found, reformat the address with a comma between state and zip code
        state = match.group(1)
        zip_code = match.group(2)
        formatted_address = address.replace(f"{state} {zip_code}", f"{state}, {zip_code}")
        return formatted_address
    else:
        # Return the original address if no match is found
        return address

# Apply the function to the 'address' column to create the new formatted address
df3['address'] = df3['address'].apply(add_comma)

# Check the result
df3.head()
# Out:
#     client_id  current_age  birth_year  birth_month  gender  \
# 0         825           53        1966           11  Female
# 5        1746           53        1966           12  Female
# 10       1718           81        1938           11  Female
# 15        708           63        1957            1  Female
# 19       1164           43        1976            9    Male
#
#                                               address  latitude  longitude  \
# 0   7481 Brydon Road, La Verne, CA, 91750, United ...     34.15    -117.76
# 5   51-17 Redfield Street, New York, NY, 11362, Un...     40.76     -73.74
# 10  Nogales Street, West Covina, CA, 91792, United...     34.02    -117.89
# 15  Market Slip, New York, NY, 10002, United State...     40.71     -73.99
# 19  24;26 Caselli Avenue, San Francisco, CA, 94114...     37.76    -122.44
#
#     per_capita_income  yearly_income  total_debt  credit_score  \
# 0               29278          59696      127613           787
# 5               37891          77254      191349           701
# 10              22681          33483         196           698
# 15             163145         249925      202328           722
# 19              53797         109687      183855           675
#
#     num_credit_cards  debt_to_income
# 0                  5        2.137714
# 5                  5        2.476881
# 10                 5        0.005854
# 15                 4        0.809555
# 19                 1        1.676179

# %%
# Define a function to extract the state abbreviation (two-letter state code)
def extract_state(address):
    # Regex pattern to capture the two-letter state abbreviation before the zip code
    match = re.search(r'\b([A-Z]{2})\b,\s*\d{5}', address)
    if match:
        return match.group(1)  # Return the state abbreviation
    else:
        return None  # Return None if no match is found

# Apply the function to the 'address' column to create the new 'state' column
df3['state'] = df3['address'].apply(extract_state)

# Reorder the columns to place 'state' directly to the right of 'address'
cols = ['client_id', 'current_age', 'birth_year', 'birth_month', 'gender', 'address', 'state', 'latitude', 'longitude', 
        'per_capita_income', 'yearly_income', 'total_debt', 'credit_score', 'num_credit_cards', 'debt_to_income']

df3 = df3[cols]

# Check the result
df3.head()
# Out:
#     client_id  current_age  birth_year  birth_month  gender  \
# 0         825           53        1966           11  Female
# 5        1746           53        1966           12  Female
# 10       1718           81        1938           11  Female
# 15        708           63        1957            1  Female
# 19       1164           43        1976            9    Male
#
#                                               address state  latitude  \
# 0   7481 Brydon Road, La Verne, CA, 91750, United ...    CA     34.15
# 5   51-17 Redfield Street, New York, NY, 11362, Un...    NY     40.76
# 10  Nogales Street, West Covina, CA, 91792, United...    CA     34.02
# 15  Market Slip, New York, NY, 10002, United State...    NY     40.71
# 19  24;26 Caselli Avenue, San Francisco, CA, 94114...    CA     37.76
#
#     longitude  per_capita_income  yearly_income  total_debt  credit_score  \
# 0     -117.76              29278          59696      127613           787
# 5      -73.74              37891          77254      191349           701
# 10    -117.89              22681          33483         196           698
# 15     -73.99             163145         249925      202328           722
# 19    -122.44              53797         109687      183855           675
#
#     num_credit_cards  debt_to_income
# 0                  5        2.137714
# 5                  5        2.476881
# 10                 5        0.005854
# 15                 4        0.809555
# 19                 1        1.676179

# %%
# Identify the rows where the 'state' column has null values
null_state_rows = df3[df3['state'].isnull()]

# Display the rows with null values in the 'state' column
print(null_state_rows[['address', 'state']])
# Out:
#                                                 address state
# 53    Hopi Road, Coconino County, AZ, United States ...  None
# 121   Maricopa County, Arizona, United States of Ame...  None
# 201   Stage Gulch Road, Sonoma County, CA, United St...  None
# 269   La Barranca Road, Riverside County, CA, United...  None
# 365   Tyson Creek Road, Benewah County, ID, United S...  None
# ...                                                 ...   ...
# 5865  Johnson Street, Ray City, Berrien County, GA, ...  None
# 5953  Madeira Island Lane, Placer County, CA, United...  None
# 5983  College Heights Boulevard (RC10), Kern County,...  None
# 6038  East 1000 South, Cassia County, ID, United Sta...  None
# 6115  Oak Street, Bienville, Bienville Parish, LA, U...  None
#
# [83 rows x 2 columns]

# %%
# Remove rows with null values in the 'state' column
df3 = df3.dropna(subset=['state'])

# Check the result
df3.info()
df3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1917 entries, 0 to 6144
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   client_id          1917 non-null   int64
#  1   current_age        1917 non-null   int64
#  2   birth_year         1917 non-null   int64
#  3   birth_month        1917 non-null   int64
#  4   gender             1917 non-null   object
#  5   address            1917 non-null   object
#  6   state              1917 non-null   object
#  7   latitude           1917 non-null   float64
#  8   longitude          1917 non-null   float64
#  9   per_capita_income  1917 non-null   int32
#  10  yearly_income      1917 non-null   int32
#  11  total_debt         1917 non-null   int32
#  12  credit_score       1917 non-null   int64
#  13  num_credit_cards   1917 non-null   int64
#  14  debt_to_income     1917 non-null   float64
# dtypes: float64(3), int32(3), int64(6), object(3)
# memory usage: 217.2+ KB
#       client_id  current_age  birth_year  birth_month  gender  \
# 0           825           53        1966           11  Female
# 5          1746           53        1966           12  Female
# 10         1718           81        1938           11  Female
# 15          708           63        1957            1  Female
# 19         1164           43        1976            9    Male
# ...         ...          ...         ...          ...     ...
# 6133        986           32        1987            7    Male
# 6136       1944           62        1957           11  Female
# 6140        185           47        1973            1  Female
# 6143       1007           66        1954            2    Male
# 6144       1110           21        1998           11  Female
#
#                                                 address state  latitude  \
# 0     7481 Brydon Road, La Verne, CA, 91750, United ...    CA     34.15
# 5     51-17 Redfield Street, New York, NY, 11362, Un...    NY     40.76
# 10    Nogales Street, West Covina, CA, 91792, United...    CA     34.02
# 15    Market Slip, New York, NY, 10002, United State...    NY     40.71
# 19    24;26 Caselli Avenue, San Francisco, CA, 94114...    CA     37.76
# ...                                                 ...   ...       ...
# 6133  34 Pierrepont Street, Village of Freeport, NY,...    NY     40.65
# 6136  57 McKim Drive, Independence, KY, 41051, Unite...    KY     38.95
# 6140  530 Trumbull Street, Union Square, Elizabeth, ...    NJ     40.66
# 6143  Mid Penn Bank, 2148 Market Street, Camp Hill, ...    PA     40.24
# 6144  Passaconaway Country Club, Waterview Circle, L...    NH     42.86
#
#       longitude  per_capita_income  yearly_income  total_debt  credit_score  \
# 0       -117.76              29278          59696      127613           787
# 5        -73.74              37891          77254      191349           701
# 10      -117.89              22681          33483         196           698
# 15       -73.99             163145         249925      202328           722
# 19      -122.44              53797         109687      183855           675
# ...         ...                ...            ...         ...           ...
# 6133     -73.58              23550          48010       87837           703
# 6136     -84.54              24218          49378      104480           740
# 6140     -74.19              15175          30942       71066           779
# 6143     -76.92              25336          54654       27241           618
# 6144     -71.48              32325          65909      181261           673
#
#       num_credit_cards  debt_to_income
# 0                    5        2.137714
# 5                    5        2.476881
# 10                   5        0.005854
# 15                   4        0.809555
# 19                   1        1.676179
# ...                ...             ...
# 6133                 3        1.829556
# 6136                 4        2.115922
# 6140                 3        2.296749
# 6143                 1        0.498426
# 6144                 2        2.750171
#
# [1917 rows x 15 columns]

# %%
# Save the full DataFrame to a new CSV file
df3.to_csv('full_dataframe.csv', index=False)

# %%
# BEGIN DATA VIZ!!!

# Generate a bar plot showing the median to debt-to-income levels by age group Pandas.
# Data Viz Recipe
# Define age bins and labels to categorize the age column into groups
age_bins = [18, 30, 40, 50, 60, 70, 100]  # Define age groups
age_labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70+']  # Age group labels

# Create a new column 'age_group' by categorizing 'age'
df3['age_group'] = pd.cut(df['current_age'], bins=age_bins, labels=age_labels, right=False)

# Group by the 'age_group' and calculate the median debt-to-income for each group
data = df2.groupby('age_group', observed=True)['debt_to_income'].median().reset_index()

# Change Canvas Size

# Create basic plot using seaborn
plt.figure(figsize=(8, 6))  # Optional: set the figure size
sns.barplot(x='age_group', y='debt_to_income', data=data, color= '#A7C957')

# Customize the plot with labels and title
plt.xlabel('Age Group')
plt.ylabel('Median Debt-to-Income Ratio')
plt.title('Median Debt-to-Income Ratio by Age Group')

# Display the plot
plt.show()
